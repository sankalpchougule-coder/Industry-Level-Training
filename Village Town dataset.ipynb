# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('A-1_NO_OF_VILLAGES_TOWNS_HOUSEHOLDS_POPULATION_AND_AREA.xlsx')
df
# Out:
#       A-1 NUMBER OF VILLAGES, TOWNS, HOUSEHOLDS, POPULATION AND AREA  \
# 0                                            State  Code
# 1                                                    NaN
# 2                                                      1
# 3                                                     00
# 4                                                     00
# ...                                                  ...
# 20018                                                NaN
# 20019                                                NaN
# 20020                                                NaN
# 20021                                                NaN
# 20022                                                NaN
#
#           Unnamed: 1                                         Unnamed: 2  \
# 0      District Code                                  Sub District Code
# 1                NaN                                                NaN
# ...

# %%
df.head()
df.tail()
df.info()
df.shape
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20023 entries, 0 to 20022
# Data columns (total 15 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   A-1 NUMBER OF VILLAGES, TOWNS, HOUSEHOLDS, POPULATION AND AREA  19994 non-null  object
#  1   Unnamed: 1                                                      20012 non-null  object
#  2   Unnamed: 2                                                      20016 non-null  object
#  3   Unnamed: 3                                                      19997 non-null  object
#  4   Unnamed: 4                                                      19997 non-null  object
#  5   Unnamed: 5                                                      19997 non-null  object
#  6   Unnamed: 6                                                      19995 non-null  object
# ...

# %%
df.describe().T
# Out:
#                                                     count unique  \
# A-1 NUMBER OF VILLAGES, TOWNS, HOUSEHOLDS, POPU...  19994     39
# Unnamed: 1                                          20012    661
# Unnamed: 2                                          20016   5948
# Unnamed: 3                                          19997      9
# Unnamed: 4                                          19997   6061
# Unnamed: 5                                          19997      7
# Unnamed: 6                                          19995    896
# Unnamed: 7                                          19994    225
# Unnamed: 8                                          19994     84
# Unnamed: 9                                          19994  13101
# Unnamed: 10                                         19995  13965
# Unnamed: 11                                         19994  13708
# Unnamed: 12                                         19994  13721
# ...

# %%
df.isnull().sum()
# Out:
# A-1 NUMBER OF VILLAGES, TOWNS, HOUSEHOLDS, POPULATION AND AREA     29
# Unnamed: 1                                                         11
# Unnamed: 2                                                          7
# Unnamed: 3                                                         26
# Unnamed: 4                                                         26
# Unnamed: 5                                                         26
# Unnamed: 6                                                         28
# Unnamed: 7                                                         29
# Unnamed: 8                                                         29
# Unnamed: 9                                                         29
# Unnamed: 10                                                        28
# Unnamed: 11                                                        29
# Unnamed: 12                                                        29
# ...

# %%
df[' Unnamed:1'] = df[' Unnamed:1'].fillna('NA')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' Unnamed:1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-567664220.py in <cell line: 0>()
# ----> 1 df[' Unnamed:1'] = df[' Unnamed:1'].fillna('NA')
#
# ...
