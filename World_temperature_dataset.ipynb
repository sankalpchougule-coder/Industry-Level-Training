# %% [markdown]
# This Project includes the Basic Data Analysis of student performance dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('World_temperature.csv')
df
# Out:
#                   utc_time           local_time   country  capital continent  \
# 0      2025-11-01 00:00:00  2025-11-01 04:00:00  Abkhazia  Sukhumi   Unknown
# 1      2025-11-01 06:00:08  2025-11-01 10:00:08  Abkhazia  Sukhumi   Unknown
# 2      2025-11-01 12:00:03  2025-11-01 16:00:03  Abkhazia  Sukhumi   Unknown
# 3      2025-11-01 18:00:10  2025-11-01 22:00:10  Abkhazia  Sukhumi   Unknown
# 4      2025-11-02 00:00:02  2025-11-02 04:00:02  Abkhazia  Sukhumi   Unknown
# ...                    ...                  ...       ...      ...       ...
# 30235  2025-11-29 18:00:25  2025-11-29 20:00:25  Zimbabwe   Harare    Africa
# 30236  2025-11-30 00:00:19  2025-11-30 02:00:19  Zimbabwe   Harare    Africa
# 30237  2025-11-30 06:00:18  2025-11-30 08:00:18  Zimbabwe   Harare    Africa
# 30238  2025-11-30 12:00:24  2025-11-30 14:00:24  Zimbabwe   Harare    Africa
# 30239  2025-11-30 18:00:22  2025-11-30 20:00:22  Zimbabwe   Harare    Africa
#
# ...

# %%
df.head()
df.tail()
df.info()
df.shape
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30240 entries, 0 to 30239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   utc_time             30240 non-null  object
#  1   local_time           30240 non-null  object
#  2   country              30240 non-null  object
#  3   capital              30240 non-null  object
#  4   continent            30240 non-null  object
#  5   temperature          30240 non-null  float64
#  6   temp_min             30240 non-null  float64
#  7   temp_max             30240 non-null  float64
#  8   humidity             30240 non-null  int64
#  9   feels_like           30240 non-null  float64
#  10  visibility           30207 non-null  float64
#  11  precipitation        30240 non-null  float64
#  12  cloudcover           30240 non-null  int64
#  13  wind_speed           30240 non-null  float64
#  14  wind_gust            30240 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                   count         mean          std     min       25%       50%  \
# temperature     30240.0    18.638015    10.105116  -41.15     11.56     21.75
# temp_min        30240.0    18.318834    10.223095  -41.15     11.01     21.51
# temp_max        30240.0    18.904847    10.046789  -41.15     11.88     21.93
# humidity        30240.0    72.543188    20.250756    5.00     63.00     77.00
# feels_like      30240.0    18.788823    11.999306  -48.15     10.59     21.74
# visibility      30207.0  9320.606250  1873.937405   20.00  10000.00  10000.00
# precipitation   30240.0     0.121339     0.903147    0.00      0.00      0.00
# cloudcover      30240.0    48.454861    36.539924    0.00     20.00     40.00
# wind_speed      30240.0     3.501963     2.499439    0.00      1.54      3.09
# wind_gust       30240.0     1.922860     3.485438    0.00      0.00      0.00
# wind_direction  30240.0   152.524868   109.813954    0.00     61.00    130.00
# ...

# %%
# Check basic info for categorical columns

cat_col = df.select_dtypes(include = ['object']).columns.tolist()
num_cols = df.select_dtypes(include = ['int64', 'float64']).columns.tolist()

print("Categorical columns:", cat_col)
print("Numeric columns:", num_cols)

for col in cat_col:
    print(f"\nValue counts for '{col}':")
    print(df[col].value_counts())
# Out:
# Categorical columns: ['utc_time', 'local_time', 'country', 'capital', 'continent', 'weather_main', 'weather_description', 'weather_icon']
# Numeric columns: ['temperature', 'temp_min', 'temp_max', 'humidity', 'feels_like', 'visibility', 'precipitation', 'cloudcover', 'wind_speed', 'wind_gust', 'wind_direction', 'pressure', 'is_day', 'weather_code']
#
# Value counts for 'utc_time':
# utc_time
# 2025-11-20 18:14:43    20
# 2025-11-07 06:00:14    20
# 2025-11-20 18:14:41    20
# 2025-11-20 18:14:50    20
# 2025-11-11 18:00:12    20
#                        ..
# 2025-11-17 12:00:07     1
# 2025-11-19 12:00:09     1
# 2025-11-21 12:00:06     1
# 2025-11-24 12:00:06     1
# 2025-11-30 18:00:22     1
# Name: count, Length: 2113, dtype: int64
#
# Value counts for 'local_time':
# local_time
# 2025-11-26 14:00:16    11
# 2025-11-23 08:00:11    11
# 2025-11-03 14:00:18    10
# 2025-11-22 14:00:15    10
# 2025-11-04 08:00:11    10
#                        ..
# 2025-11-19 15:00:10     1
# ...

# %%
# Check missing values

df.isnull().sum()
# Out:
# utc_time                0
# local_time              0
# country                 0
# capital                 0
# continent               0
# temperature             0
# temp_min                0
# temp_max                0
# humidity                0
# feels_like              0
# visibility             33
# precipitation           0
# cloudcover              0
# wind_speed              0
# wind_gust               0
# wind_direction          0
# pressure                0
# is_day                  0
# weather_code            0
# weather_main            0
# weather_description     0
# weather_icon            0
# dtype: int64

# %%
#Check for duplicate rows

print("Number of duplicate rows:",df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
df_filled = df.fillna(df.mean(numeric_only=True))

print("\nMissing values after:")
print(df_filled.isnull().sum())

df_filled.to_csv("World_temperature_cleaned.csv",index=False)

df_filled.head()
# Out:
# Missing values after:
# utc_time               0
# local_time             0
# country                0
# capital                0
# continent              0
# temperature            0
# temp_min               0
# temp_max               0
# humidity               0
# feels_like             0
# visibility             0
# precipitation          0
# cloudcover             0
# wind_speed             0
# wind_gust              0
# wind_direction         0
# pressure               0
# is_day                 0
# weather_code           0
# weather_main           0
# weather_description    0
# weather_icon           0
# dtype: int64
#               utc_time           local_time   country  capital continent  \
# 0  2025-11-01 00:00:00  2025-11-01 04:00:00  Abkhazia  Sukhumi   Unknown
# 1  2025-11-01 06:00:08  2025-11-01 10:00:08  Abkhazia  Sukhumi   Unknown
# 2  2025-11-01 12:00:03  2025-11-01 16:00:03  Abkhazia  Sukhumi   Unknown
# ...

# %%
#Basic sanity check

print("Country:", df['country'].min(), "to", df['country'].max())
print("temperature:", df['temperature'].min(), "to", df['temperature'].max())
print("Humidity:", df['humidity'].min(), "to", df['humidity'].max())
# Out:
# Country: Abkhazia to Zimbabwe
# temperature: -41.15 to 39.99
# Humidity: 5 to 100
