# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Bookings.csv')
df
# Out:
#                        Date      Time     Booking_ID        Booking_Status  \
# 0       2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1       2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2       2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3        2024-07-22 3:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4        2024-07-02 9:02:00  09:02:00  CNR1797421769               Success
# ...                     ...       ...            ...                   ...
# 103019   2024-07-31 9:06:00  09:06:00  CNR9488489435               Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
# ...

# %%
df.head()
df.tail()
# Out:
#                        Date      Time     Booking_ID Booking_Status  \
# 103019   2024-07-31 9:06:00  09:06:00  CNR9488489435        Success
# 103020  2024-07-31 15:12:00  15:12:00  CNR3151743100        Success
# 103021  2024-07-31 13:59:00  13:59:00  CNR1286151233        Success
# 103022  2024-07-31 14:56:00  14:56:00  CNR2027162035        Success
# 103023  2024-07-31 13:57:00  13:57:00  CNR9770709721        Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# 103019   CID371654   Prime Plus      Richmond Town        Varthur  245.0
# 103020   CID334158         Auto        Vijayanagar  Richmond Town   84.0
# 103021   CID113188    Prime SUV  Bannerghatta Road       JP Nagar   35.0
# 103022   CID118301        eBike        Indiranagar    Magadi Road  210.0
# 103023   CID217959         Auto             Ulsoor         Hennur  175.0
#
#         C_TAT  ... Canceled_Rides_by_Driver Incomplete_Rides  \
# ...

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  object
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  object
#  3   Booking_Status              103024 non-null  object
#  4   Customer_ID                 103024 non-null  object
#  5   Vehicle_Type                103024 non-null  object
#  6   Pickup_Location             103024 non-null  object
#  7   Drop_Location               103024 non-null  object
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   object
#  11  Canceled_Rides_by_Driver    18434 non-null   object
# ...

# %%
df.describe()
# Out:
#               V_TAT         C_TAT  Booking_Value  Ride_Distance  \
# count  63967.000000  63967.000000  103024.000000  103024.000000
# mean     170.876952     84.873372     548.751883      14.189927
# std       80.803640     36.005100     536.541221      15.776270
# min       35.000000     25.000000     100.000000       0.000000
# 25%       98.000000     55.000000     242.000000       0.000000
# 50%      168.000000     85.000000     386.000000       8.000000
# 75%      238.000000    115.000000     621.000000      26.000000
# max      308.000000    145.000000    2999.000000      49.000000
#
#        Driver_Ratings  Customer_Rating  Unnamed: 20
# count    63967.000000     63967.000000          0.0
# mean         3.997457         3.998313          NaN
# std          0.576834         0.578957          NaN
# min          3.000000         3.000000          NaN
# 25%          3.500000         3.500000          NaN
# 50%          4.000000         4.000000          NaN
# ...

# %%
df.describe().T
# Out:
#                     count        mean         std    min    25%    50%    75%  \
# V_TAT             63967.0  170.876952   80.803640   35.0   98.0  168.0  238.0
# C_TAT             63967.0   84.873372   36.005100   25.0   55.0   85.0  115.0
# Booking_Value    103024.0  548.751883  536.541221  100.0  242.0  386.0  621.0
# Ride_Distance    103024.0   14.189927   15.776270    0.0    0.0    8.0   26.0
# Driver_Ratings    63967.0    3.997457    0.576834    3.0    3.5    4.0    4.5
# Customer_Rating   63967.0    3.998313    0.578957    3.0    3.5    4.0    4.5
# Unnamed: 20           0.0         NaN         NaN    NaN    NaN    NaN    NaN
#
#                     max
# V_TAT             308.0
# C_TAT             145.0
# Booking_Value    2999.0
# Ride_Distance      49.0
# Driver_Ratings      5.0
# Customer_Rating     5.0
# Unnamed: 20         NaN

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns =['Vehicle Images', 'Unnamed: 20'], inplace = True)

# %%
df.shape
# Out:
# (103024, 19)

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer    92525
# Canceled_Rides_by_Driver      84590
# Incomplete_Rides              39057
# Incomplete_Rides_Reason       99098
# Booking_Value                     0
# Payment_Method                39057
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# dtype: int64

# %%
df['Canceled_Rides_by_Customer'] = df['Canceled_Rides_by_Customer'].fillna('NA')
df['Canceled_Rides_by_Driver'] = df['Canceled_Rides_by_Driver'].fillna('NA')
df['Incomplete_Rides'] = df['Incomplete_Rides'].fillna('NA')
df['Incomplete_Rides_Reason'] = df['Incomplete_Rides_Reason'].fillna('NA')
df['Payment_Method'] = df['Payment_Method'].fillna('NA')

# %%
print(df.isnull().sum())
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer        0
# Canceled_Rides_by_Driver          0
# Incomplete_Rides                  0
# Incomplete_Rides_Reason           0
# Booking_Value                     0
# Payment_Method                    0
# Ride_Distance                     0
# Driver_Ratings                39057
# Customer_Rating               39057
# dtype: int64

# %%
df['Driver_Ratings'] = pd.to_numeric(df['Driver_Ratings'], errors ='coerce')
df['Customer_Rating'] = pd.to_numeric(df['Customer_Rating'], errors ='coerce')
df['Driver_Ratings'] = df['Driver_Ratings'].fillna(3).clip(3,5)
df['Customer_Rating'] = df['Customer_Rating'].fillna(3).clip(3,5)

# %%
print(df.isnull().sum())
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         39057
# C_TAT                         39057
# Canceled_Rides_by_Customer        0
# Canceled_Rides_by_Driver          0
# Incomplete_Rides                  0
# Incomplete_Rides_Reason           0
# Booking_Value                     0
# Payment_Method                    0
# Ride_Distance                     0
# Driver_Ratings                    0
# Customer_Rating                   0
# dtype: int64

# %%
df['V_TAT'] = df['V_TAT'].fillna(df['V_TAT'].median())
df['C_TAT'] = df['C_TAT'].fillna(df['C_TAT'].median())

# %%
print(df.isnull().sum())
# Out:
# Date                          0
# Time                          0
# Booking_ID                    0
# Booking_Status                0
# Customer_ID                   0
# Vehicle_Type                  0
# Pickup_Location               0
# Drop_Location                 0
# V_TAT                         0
# C_TAT                         0
# Canceled_Rides_by_Customer    0
# Canceled_Rides_by_Driver      0
# Incomplete_Rides              0
# Incomplete_Rides_Reason       0
# Booking_Value                 0
# Payment_Method                0
# Ride_Distance                 0
# Driver_Ratings                0
# Customer_Rating               0
# dtype: int64

# %%
df.to_csv('cleaned_bookings_dataset.csv')
